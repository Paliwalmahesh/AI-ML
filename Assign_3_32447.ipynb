# %% [markdown]
# Name: Mahesh Dhanraj Paliwal (32447)
# linear regression

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('Bwt.csv')
df_binary = df[['bwt','age']]

# %%
X = np.array(df_binary['age']).reshape(-1, 1)
y = np.array(df_binary['bwt']).reshape(-1, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
regr = LinearRegression() 
regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
print("Coefficients", regr.coef_[0])
print("intercept:",regr.intercept_)
# Out:
# -0.008699171656687321
# Coefficients [0.14616119]
# intercept: [115.23626904]

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test, y_test, color ='b')
plt.plot(X_test, y_pred, color ='k')
plt.xlabel("Age")
plt.ylabel("Birth Weight")
plt.title("Age vs Birth Weight")
plt.show()

# %%
df_bin = df[['weight','bwt']]

# %%
X_a = np.array(df_bin['bwt']).reshape(-1, 1)
y_a = np.array(df_bin['weight']).reshape(-1, 1)

# %%
X_train_a, X_test_a, y_train_a, y_test_a = train_test_split(X_a, y_a, test_size = 0.25)

# %%
regr1 = LinearRegression() 
regr1.fit(X_train_a, y_train_a)
print(regr.score(X_a, y_a))
# Out:
# -0.017828263636464392

# %%
y_pred_a = regr1.predict(X_test_a)
plt.scatter(X_test_a, y_test_a, color ='r')
plt.plot(X_test_a, y_pred_a, color ='k')
print("Coefficients", regr1.coef_[0])
print("intercept:",regr1.intercept_)
plt.xlabel("Mothers Weight")
plt.ylabel("Birth Weight")
plt.title("Mothers Weight vs Birth Weight")
plt.show()
# Out:
# Coefficients [0.18926501]
# intercept: [105.73552459]

# %% [markdown]
# Conclusion:From both the graph we get nearly flat line that means baby's birth weight is heard to predict from Mother's age as well as Mother's weight
